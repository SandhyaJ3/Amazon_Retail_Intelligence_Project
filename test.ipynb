# %%
1+1
# Out:
# 2

# %%
from src.data_loader import load_data

df = load_data()

df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.data_loader import load_data
#       2
#       3 df = load_data()
#       4
#
# ImportError: cannot import name 'load_data' from 'src.data_loader' (c:\Users\Sandhya Jai\Documents\PythonAnalytics\src\data_loader.py)
